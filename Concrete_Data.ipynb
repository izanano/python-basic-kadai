# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score,mean_absolute_error
# %matplotlib inline

# %%
df = pd.read_csv('Concrete_Data.csv',index_col = 0)

# %%
df.head

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
x.head

# %%
y.head

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2)

# %%
x_train.head()

# %%
reg = RandomForestRegressor()

# %%
reg.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = reg.predict(x_test)

# %%
y_pred

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8997233464089349

# %%
np.sqrt(mean_absolute_error(y_test,y_pred))
# Out:
# 1.9126599613105697

# %%
y_pred_train = reg.predict(x_train)
#y_trainを評価するために記述する

# %%
plt.figure(figsize = (6,6))
plt.scatter(y_train,y_pred_train,label = 'train')
plt.scatter(y_test,y_pred,label = 'test')
plt.plot(np.arange(0,60),np.arange(0,60),linestyle = 'dashed',color = 'gray')
plt.xlabel('true')
plt.ylabel('prediced')
plt.legend()

# %%
reg.feature_importances_
# Out:
# array([0.04168237, 0.11587159, 0.19208468, 0.11189514, 0.07782245,
#        0.10955673, 0.35108703])

# %%
plt.bar(np.arange(len(reg.feature_importances_)), reg.feature_importances_)
plt.xticks(np.arange(len(x.columns)), x.columns, rotation=90)
plt.ylabel("Contribution")
# Out:
# Text(0, 0.5, 'Contribution')

# %%
plt.scatter(df['Age (day)'],['Concrete compressive strength(MPa, megapascals)'])
#同じサイズにしなければならないと出ます。ミスがどこかがわかりません。
